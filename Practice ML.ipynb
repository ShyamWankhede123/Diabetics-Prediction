# %%
import pandas as pd

# %%
import sklearn.linear_model import LinearRegression
lir = LinearRegression()
# Out:
#   File "C:\Users\SHYAM WANKHEDE\AppData\Local\Temp\ipykernel_30328\537029723.py", line 1
#     import sklearn.linear_model import LinearRegression
#                                      ^
# SyntaxError: invalid syntax

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/shsarv/Machine-Learning-Projects/main/Diabetes%20Prediction%20%5BEND%202%20END%5D/dataset/kaggle_diabetes.csv")

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# 1                        0.233   23        0
# 2                        0.630   31        1
# 3                        0.365   24        1
# 4                        0.536   21        0
# ...                        ...  ...      ...
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0
#
# [2000 rows x 9 columns]

# %%
temp= df[(df['SkinThickness']==0 ) & (df['Age']!=0)]
skinpred= lir.predict(temp[['BMI','Age']])
df.loc[temp.index,'Skinthickness'] = skinpred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30328\3791874798.py in <module>
#       1 temp= df[(df['SkinThickness']==0 ) & (df['Age']!=0)]
# ----> 2 skinpred= lir.predict(temp[['BMI','Age']])
#       3 df.loc[temp.index,'Skinthickness'] = skinpred
#
# NameError: name 'lir' is not defined
